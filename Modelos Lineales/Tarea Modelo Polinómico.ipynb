# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (15,12)

# %% [markdown]
# ### Cargar datos

# %%
df = pd.read_excel("Tarea Ajustar Modelo.xlsx")
df.shape
# Out:
# (18, 2)

# %% [markdown]
# # MODELO POLINOMIO 2

# %%
x = df["X"].to_numpy()
y = df["Y"].to_numpy()

# %%
x= x[:,np.newaxis]
y= y[:,np.newaxis]

# %%
inds = x.ravel().argsort()      
x = x.ravel()[inds].reshape(-1,1)
y = y[inds]

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_features= PolynomialFeatures(degree=2)
xp = polynomial_features.fit_transform(x)
xp.shape
# Out:
# (18, 3)

# %%
import statsmodels.api as sm

model = sm.OLS(y, xp).fit()
ypred = model.predict(xp)

# %%
plt.scatter(x,y)
plt.plot(x,ypred)
plt.title("Polinómio de Grado 2", size = 26)
# Out:
# Text(0.5, 1.0, 'Polinómio de Grado 2')

# %%
model.summary()
# Out:
# C:\Users\actda\anaconda3\lib\site-packages\scipy\stats\stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     395.5
# Date:                Thu, 28 Oct 2021   Prob (F-statistic):           1.06e-13
# Time:                        10:08:13   Log-Likelihood:                -55.490
# No. Observations:                  18   AIC:                             117.0
# Df Residuals:                      15   BIC:                             119.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# ## MODELO POLINOMIO 3

# %%
polynomial_features3= PolynomialFeatures(degree=3)
xp3 = polynomial_features3.fit_transform(x)
xp3.shape

model3 = sm.OLS(y, xp3).fit()
ypred3 = model3.predict(xp3) 

plt.scatter(x,y)
plt.plot(x,ypred3)
plt.title("Polinómio de Grado 3", size = 26)
# Out:
# Text(0.5, 1.0, 'Polinómio de Grado 3')

# %%
model3.summary()
# Out:
# C:\Users\actda\anaconda3\lib\site-packages\scipy\stats\stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     516.7
# Date:                Thu, 28 Oct 2021   Prob (F-statistic):           1.44e-14
# Time:                        10:08:14   Log-Likelihood:                -48.901
# No. Observations:                  18   AIC:                             105.8
# Df Residuals:                      14   BIC:                             109.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# ## MODELO POLINOMIO 4

# %%
polynomial_features4= PolynomialFeatures(degree=4)
xp4 = polynomial_features4.fit_transform(x)
xp4.shape
# Out:
# (18, 5)

# %%
model4 = sm.OLS(y, xp4).fit()
ypred4 = model4.predict(xp4)

# %%
plt.scatter(x,y)
plt.plot(x,ypred4)
plt.title("Polinómio de Grado 4", size = 26)
# Out:
# Text(0.5, 1.0, 'Polinómio de Grado 4')

# %%
model4.summary()
# Out:
# C:\Users\actda\anaconda3\lib\site-packages\scipy\stats\stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     501.5
# Date:                Thu, 28 Oct 2021   Prob (F-statistic):           1.77e-14
# Time:                        10:51:42   Log-Likelihood:                -49.168
# No. Observations:                  18   AIC:                             106.3
# Df Residuals:                      14   BIC:                             109.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...

# %%
model4.params
# Out:
# array([-1.67010972e-01, -8.03993113e+01,  1.30596679e-01, -7.06943923e-05,
#         1.27537000e-08])
